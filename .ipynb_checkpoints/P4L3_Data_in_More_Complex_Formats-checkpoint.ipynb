# %%
# what you would need to import in this lesson

import xml.etree.ElementTree as ET
import pprint
from bs4 import BeautifulSoup
import lxml
import requests
import json

# %% [markdown]
# ## 1. Welcome to Lesson 2

# %% [markdown]
# ## 2. Intro to XML

# %% [markdown]
# ## 3. XML Design Principles

# %%
# 1) Data transfer from an application's producer to its consumer
# 2) Easy to write code to read and write XML
# 3) Documentation validation
# 4) Human readable
# 5) Support a wide variety of applications

# for more information:
# https://www.w3.org/TR/xml/#sec-origin-goals

# %% [markdown]
# ## 4. XML in Practice

# %% [markdown]
# ## 5. Fundamentals of XML

# %% [markdown]
# ## 6. XML Resources

# %%
# W3Shools
#  https://www.w3schools.com/xml/xml_whatis.asp
# tizag.com
#  http://www.tizag.com/xmlTutorial/index.php

# %% [markdown]
# ## 7. Parsing XML

# %%
#  import xml.etree.ElementTree moddule
import xml.etree.ElementTree as ET

# parse research article into "tree"
tree = ET.parse('P4L3_Resources/exampleresearcharticle.xml')
root = tree.getroot()

# use tag attribute to print out the tag name of each child element

print "\nChildren of root:"
for child in root:
    print child.tag
# Out:
# Children of root:
# ui
# ji
# fm
# bdy
# bm

# %%
# find title element by using text attribute 

title = root.find('./fm/bibl/title')
title_text = ""
for p in title:
    title_text += p.text
print "\nTitle:\n", title_text
# Out:
# Title:
# Standardization of the functional syndesmosis widening by dynamic U.S examination

# %%
print "\Author email addresses:"
for a in root.findall('fm/bibl/aug/au'):
    email = a.find('email')
    if email is not None:
        print email.text
# Out:
# \Author email addresses:
# omer@extremegate.com
# mcarmont@hotmail.com
# laver17@gmail.com
# nyska@internet-zahav.net
# kammarh@gmail.com
# gideon.mann.md@gmail.com
# barns.nz@gmail.com
# eukots@gmail.com

# %%
# xpath syntax
# https://www.w3schools.com/xml/xpath_syntax.asp

# %% [markdown]
# ## 8. Quiz: Extracting Data

# %%
#####################################
#                 8                 #
#####################################
'''
# !/usr/bin/env python
Your task here is to extract data from xml on authors of an article
and add it to a list, one item for an author.
See the provided data structure for the expected format.
The tags for first name, surname and email should map directly
to the dictionary keys
'''
# Out:
# '\n!/usr/bin/env python\nYour task here is to extract data from xml on authors of an article\nand add it to a list, one item for an author.\nSee the provided data structure for the expected format.\nThe tags for first name, surname and email should map directly\nto the dictionary keys\n'

# %%
article_file = "P4L3_Resources/exampleresearcharticle.xml"

# %%
def get_root(fname):
    tree = ET.parse(fname)
    return tree.getroot()

# %%
root = get_root(article_file)

# %%
root
# Out:
# <Element 'art' at 0x104668850>

# %%
def get_authors(root):
    authors = []
    for author in root.findall('./fm/bibl/aug/au'):
        data = {
                "fnm": None,
                "snm": None,
                "email": None
        }

        # YOUR CODE HERE
        data["fnm"] = author.find('./fnm').text
        data["snm"] = author.find('./snm').text
        data["email"] = author.find('./email').text
      
        authors.append(data)

    return authors

# %%
def test():
    solution = [{'fnm': 'Omer', 'snm': 'Mei-Dan', 'email': 'omer@extremegate.com'}, {'fnm': 'Mike', 'snm': 'Carmont', 'email': 'mcarmont@hotmail.com'}, {'fnm': 'Lior', 'snm': 'Laver', 'email': 'laver17@gmail.com'}, {'fnm': 'Meir', 'snm': 'Nyska', 'email': 'nyska@internet-zahav.net'}, {'fnm': 'Hagay', 'snm': 'Kammar', 'email': 'kammarh@gmail.com'}, {'fnm': 'Gideon', 'snm': 'Mann', 'email': 'gideon.mann.md@gmail.com'}, {'fnm': 'Barnaby', 'snm': 'Clarck', 'email': 'barns.nz@gmail.com'}, {'fnm': 'Eugene', 'snm': 'Kots', 'email': 'eukots@gmail.com'}]
    
    root = get_root(article_file)
    data = get_authors(root)

    assert data[0] == solution[0]
    assert data[1]["fnm"] == solution[1]["fnm"]

# %%
test()

# %% [markdown]
# ## 9. Handling Attributes

# %%
#####################################
#                 9                 #
#####################################

#!/usr/bin/env python
# Your task here is to extract data from xml on authors of an article
# and add it to a list, one item for an author.
# See the provided data structure for the expected format.
# The tags for first name, surname and email should map directly
# to the dictionary keys, but you have to extract the attributes from the "insr" tag
# and add them to the list for the dictionary key "insr"

# %%
# read data
article_file = "P4L3_Resources/exampleResearchArticle.xml"

# %%
def get_root(fname):
    tree = ET.parse(fname)
    return tree.getroot()

# %%
def get_authors(root):
    authors = []
    for author in root.findall('./fm/bibl/aug/au'):
        data = {
                "fnm": None,
                "snm": None,
                "email": None,
                "insr":[]
        }

        # YOUR CODE HERE
        data["fnm"] = author.find('./fnm').text
        data["snm"] = author.find('./snm').text
        data["email"] = author.find('./email').text
        insr = author.findall('./insr')
        for i in insr:
            data["insr"].append(i.attrib["iid"])

        authors.append(data)

    return authors

# %%
def test():
    solution = [{'insr': ['I1'], 'fnm': 'Omer', 'snm': 'Mei-Dan', 'email': 'omer@extremegate.com'},
                {'insr': ['I2'], 'fnm': 'Mike', 'snm': 'Carmont', 'email': 'mcarmont@hotmail.com'},
                {'insr': ['I3', 'I4'], 'fnm': 'Lior', 'snm': 'Laver', 'email': 'laver17@gmail.com'},
                {'insr': ['I3'], 'fnm': 'Meir', 'snm': 'Nyska', 'email': 'nyska@internet-zahav.net'},
                {'insr': ['I8'], 'fnm': 'Hagay', 'snm': 'Kammar', 'email': 'kammarh@gmail.com'},
                {'insr': ['I3', 'I5'], 'fnm': 'Gideon', 'snm': 'Mann', 'email': 'gideon.mann.md@gmail.com'},
                {'insr': ['I6'], 'fnm': 'Barnaby', 'snm': 'Clarck', 'email': 'barns.nz@gmail.com'},
                {'insr': ['I7'], 'fnm': 'Eugene', 'snm': 'Kots', 'email': 'eukots@gmail.com'}]

    root = get_root(article_file)
    data = get_authors(root)

    assert data[0] == solution[0]
    assert data[1]["insr"] == solution[1]["insr"]

# %%
test()

# %% [markdown]
# ## 10. Intro to Screen Scraping

# %% [markdown]
# ## 11. Introducing the Working Example

# %%
# Check the AirTrans website page source in your browser!
# view-source:https://www.transtats.bts.gov/Data_Elements.aspx?Data=2

# %% [markdown]
# ## 12. Example Details

# %% [markdown]
# ## 13. Where's the Data?

# %% [markdown]
# ## 14. Procedure

# %%
# Data Wrangling Procedure for this example
# 1. Build list of carrier values
# 2. Build list of airport values
# 3. Make http requests to download all data
# 4. Then parse the data files
#

# %% [markdown]
# ## 15. Extracting Entities

# %%
# AirTrans website
# https://www.transtats.bts.gov/Data_Elements.aspx?Data=2

# Download list of carriers and airports from this page and save
# P4L3_Resources/DataElements.html

# %%
# import BeautifulSoupr which enable us to parse the document tree 
# it is similar to elementary for parsing XML
# we are using beautiful soup 4
from bs4 import BeautifulSoup

# Learn more about Beautiful Soup
# https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %%
def options(soup, id):
    option_values = []
    
    carrier_list = soup.find(id=id)
    # find the first descendant document tree 
    # where the ID attribute for the element is id
    
    for option in carrier_list.find_all('option'):
    # find_all will find all of the sentence instead of just the first one
        
        option_values.append(option['value'])
        # build up a list of all the values
        # by pulling out the value of their value attribute
        
    return option_values

# %%
def print_list(label, codes):
    print "\n%s:" % label
    for c in codes:
        print c

# %%
def main():
    soup = BeautifulSoup(open("P4L3_Resources/DataElements.html"))
    # we get "soup" in response to call BeautifulSoup on the local file
    # "soup" is the top level element for this particular HTML document 
    
    codes = options(soup, 'CarrierList') 
    # right-click on the carrier selection and choose "inspect"
    # to see what is the ID attribute for this particular element
    
    print_list("Carriers", codes)
    
    codes = options(soup, 'AirportList')
    print_list("Airports", codes)

# %%
main()
# Out:
# Carriers:
# All
# AllUS
# AllForeign
# AS
# G4
# AA
# 5Y
# DL
# MQ
# EV
# F9
# HA
# B6
# OO
# WN
# NK
# UA
# VX
#
# Airports:
# All
# AllMajors
# ATL
# BWI
# BOS
# CLT
# MDW
# ORD
# DAL
# DFW
# DEN
# DTW
# FLL
# IAH
# LAS
# LAX
# MIA
# MSP
# JFK
# LGA
# EWR
# MCO
# PHL
# PHX
# PDX
# SLC
# SAN
# SFO
# SEA
# TPA
# DCA
# IAD
# AllOthers
# UXM
# ABR
# ABI
# DYS
# ADK
# VZF
# BQN
# AKK
# KKI
# AKI
# AKO
# AKC
# CAK
# 7AK
# KQA
# AUK
# ALM
# ALS
# ABY
# ALB
# ABQ
# ZXB
# WKK
# AED
# AEX
# AXN
# AET
# ABE
# AIA
# APN
# DQH
# AOO
# AMA
# ABL
# OQZ
# AOS
# OTS
# AKP
# EDF
# DQL
# MRI
# ANC
# AND
# AGN
# ANI
# ANN
# ANB
# ANV
# ATW
# ACV
# ARC
# ADM
# AVL
# HTS
# ASE
# AST
# AHN
# AKB
# PDK
# FTY
# GA3
# ACY
# ATT
# ATK
# MER
# AUO
# AGS
# AUG
# AUS
# A28
# BFL
# BGR
# BHB
# BRW
# BTI
# BQV
# A2K
# BTR
# BTL
# AK2
# A56
# BTY
# BPT
# BVD
# WBQ
# BKW
# BED
# A11
# KBE
# BLV
# BLI
# BLM
# JVL
# BVU
# BJI
# RDM
# BEH
# BET
# BTT
# BVY
# OQB
# A50
# BIC
# BIG
# BGQ
# BMX
# PWR
# A85
# BIL
# BIX
# ...

# %% [markdown]
# ## 16. Beginning to Build Our http Requests

# %%
# point: any time you are doing a scraping task, 
# you absolutely have to understand exactly how the site expects requests

# %%
# first step: figure out what URL we have to access
# and what HTTP method we need to use

# %% [markdown]
# ## 17. More Work Than We Thought

# %%
# second step: use browser to understand expected requests to receive results

# %%
# look at the network tab
# check the post request when you submit the form

# %%
# click the header tab 
# and you will see the Form Data as below

# %%
# Form Data (8)
# __EVENTTARGET:
# __EVENTARGUMENT:
# __VIEWSTATE:/wEPDwUJNTUyNTIyMzEzDxYOHgdzdHJDb25uBVpQcm92aWRlcj0u...
# __VIEWSTATEGENERATOR:8E3A4798
# __EVENTVALIDATION:/wEdAN0JdbmZlENohTMW3itnA8gno/c8W+KtN+Mo2aSUQq...
# CarrierList:VX
# AirportList:BOS
# Submit:Submit

# %% [markdown]
# ## 18. Quiz: How Many Form Elements

# %% [markdown]
# ## 19. Using Beautiful Soup

# %%
# third step: build the HTTP request to pass the form elements

# %%
#####################################
#                 19                #
#####################################

#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Please note that the function 'make_request' is provided for your reference only.
# You will not be able to to actually use it from within the Udacity web UI.
# Your task is to process the HTML using BeautifulSoup, extract the hidden
# form field values for "__EVENTVALIDATION" and "__VIEWSTATE" and set the appropriate
# values in the data dictionary.
# All your changes should be in the 'extract_data' function

# %%
from bs4 import BeautifulSoup
import lxml
import requests
import json

# %%
html_page = "P4L3_Resources/page_source.html"

# %%
def extract_data(page):
    data = {"eventvalidation": "",
            "viewstate": ""}
    
    with open(page, "r") as html:
        
        # do something here to find the necessary values
        soup = BeautifulSoup(html,"html") # "lxml" is a faster parser, but "html" works, too
        data['eventvalidation'] = soup.find(id='__EVENTVALIDATION')['value']
        data['viewstate'] = soup.find(id='__VIEWSTATE')['value']
 
        pass

    return data

# %%
def make_request(data):
    eventvalidation = data["eventvalidation"]
    viewstate = data["viewstate"]

    r = requests.post("http://www.transtats.bts.gov/Data_Elements.aspx?Data=2",
                    data={'AirportList': "BOS",
                          'CarrierList': "VX",
                          'Submit': 'Submit',
                          "__EVENTTARGET": "",
                          "__EVENTARGUMENT": "",
                          "__EVENTVALIDATION": eventvalidation,
                          "__VIEWSTATE": viewstate
                    })

    return r.text

# %%
def test():
    data = extract_data(html_page)
    assert data["eventvalidation"] != ""
    assert data["eventvalidation"].startswith("/wEWjAkCoIj1ng0")
    assert data["viewstate"].startswith("/wEPDwUKLTI")

# %%
test()

# %% [markdown]
# ## 20. Broken Requests

# %%
# summary of the steps
# 1. submit an initial request
# 2. use the response that we get back to make a subsequent post request
# 3. submit the post request

# %%
# make an initial get request
r = requests.get("https://www.transtats.bts.gov/Data_Elements.aspx?Data=2")

# %%
# parse the response to get the viewstate and eventvalidation
soup = BeautifulSoup(r.text)
viewstate_element = soup.find(id="__VIEWSTATE")
viewstate = viewstate_element["value"]
eventvalidation_element = soup.find(id="__EVENTVALIDATION")
eventvalidation = eventvalidation_element["value"]

# %%
# submit a subsequent post request
r = requests.post("https://www.transtats.bts.gov/Data_Elements.aspx?Data=2",
                  data={'AirportList' : "BOS",
                        'CarrierList' : "VX",
                        'Submit' : "Submit",
                        '__EVENTTARGET' : "",
                        '__EVENTARGUMENT' : "",
                        '__EVENTVALIDATION' : eventvalidation,
                        '__VIEWSTATE' : viewstate})

# %%
# write out to a file
f = open("P4L3_Resources/virgin_and_logan_airport.html","w")
f.write(r.text)

# %%
# However, when you open the "virgin_and_logan_airport.html" file, you will get the error message below.

# Note
# A syntax error has occurred.
# The reason is probably that you have used a bookmarked URL with an invalid parameter.
# Please click TranStats on the sidebar to start from the TranStats homepage. 
# If the problem persists, please contact ritainfo@dot.gov.

# %% [markdown]
# ## 21. Best Practices for Scraping

# %%
# Best practices for scraping are below
# 1. look at how a browser itself makes requests
    # use developer tools or look at the wire traffic if you really needed to
# 2. emulate that in your code
# 3. if stuff blows up, look at your HTTP traffic
# 4. return to 1 until it works

# %% [markdown]
# ## 22. Scraping Solutionåç

# %%
# Cookie maintained by the browser might be one of the problems

# %%
# modified code
# use Session object to do both get and post
# so that session information for the first request will be maintained and passed along for the post request
s = requests.Session()

r = s.get("https://www.transtats.bts.gov/Data_Elements.aspx?Data=2")
soup = BeautifulSoup(r.text)
viewstate_element = soup.find(id="__VIEWSTATE")
viewstate = viewstate_element["value"]
eventvalidation_element = soup.find(id="__EVENTVALIDATION")
eventvalidation = eventvalidation_element["value"]

r = s.post("https://www.transtats.bts.gov/Data_Elements.aspx?Data=2",
                  data={'AirportList' : "BOS",
                        'CarrierList' : "VX",
                        'Submit' : "Submit",
                        '__EVENTTARGET' : "",
                        '__EVENTARGUMENT' : "",
                        '__EVENTVALIDATION' : eventvalidation,
                        '__VIEWSTATE' : viewstate})

f = open("P4L3_Resources/virgin_and_logan_airport_v2.html","w")
f.write(r.text)

# %% [markdown]
# ## 23. Wrap-Up

# %%
# last step: put all the pieces together
